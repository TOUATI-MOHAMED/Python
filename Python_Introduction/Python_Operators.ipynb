# %% [markdown]
# <a href="https://colab.research.google.com/github/TOUATI-MOHAMED/Python/blob/master/Python_Introduction/Python_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Operators**
# This Section , you'll learn everything about different types of operators in Python, their syntax and how to use them with examples.
#
# **What are operators in python?**
#
# Operators are special symbols in Python that carry out arithmetic or logical computation. The value that the operator operates on is called the operand.
#
# **For example:**
#
#     >>> 2+3
#
# 5
#
# Here, + is the operator that performs addition. 2 and 3 are the operands and 5 is the output of the operation.

# %% [markdown]
# # **Arithmetic operators**
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication etc.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example #1: Arithmetic operators in Python**

# %%
x = 15
y = 4
# Output: x + y = 19

print('x + y =',x+y)
# Output: x - y = 11
print('x - y =',x-y)
# Output: x * y = 60
print('x * y =',x*y)
# Output: x / y = 3.75
print('x / y =',x/y)
# Output: x // y = 3
print('x // y =',x//y)
# Output: x ** y = 50625
print('x ** y =',x**y)
# Out:
# "''\nprint('x + y =',x+y)\n# Output: x - y = 11\nprint('x - y =',x-y)\n# Output: x * y = 60\nprint('x * y =',x*y)\n# Output: x / y = 3.75\nprint('x / y =',x/y)\n# Output: x // y = 3\nprint('x // y =',x//y)\n# Output: x ** y = 50625\nprint('x ** y =',x**y)\n"

# %% [markdown]
# # **Comparison operators**
#
# Comparison operators are used to compare values. It either returns True or False according to the condition.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example #2: Comparison operators in Python**

# %%
x = 10
y = 12
# Output: x > y is False
print('x > y  is',x>y)
# Output: x < y is True
print('x < y  is',x<y)
# Output: x == y is False
print('x == y is',x==y)
# Output: x != y is True
print('x != y is',x!=y)
# Output: x >= y is False
print('x >= y is',x>=y)
# Output: x <= y is True
print('x <= y is',x<=y)
# Out:
# x > y  is False
# x < y  is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %% [markdown]
# # **Logical operators**
# Logical operators are the and, or, not operators.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example #3: Logical Operators in Python**

# %%
x = True
y = False
# Output: x and y is False
print('x and y is',x and y)
# Output: x or y is True
print('x or y is',x or y)
# Output: not x is False
print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %% [markdown]
# # **Bitwise operators**
# Bitwise operators act on operands as if they were string of binary digits. It operates bit by bit, hence the name.
#
# For example, 2 is 10 in binary and 7 is 111.
#
# In the table below: Let x = 10 (0000 1010 in binary) and y = 4 (0000 0100 in binary)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assignment operators
# Assignment operators are used in Python to assign values to variables.
#
# a = 5 is a simple assignment operator that assigns the value 5 on the right to the variable a on the left.
#
# There are various compound operators in Python like a += 5 that adds to the variable and later assigns the same. It is equivalent to a = a + 5.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Special operators**
# Python language offers some special type of operators like the identity operator or the membership operator. They are described below with examples.

# %% [markdown]
# # **Identity  operators**
# is and is not are the identity operators in Python. They are used to check if two values (or variables) are located on the same part of the memory. Two variables that are equal does not imply that they are identical.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example #4: Identity operators in Python**

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
# Output: False
print(x1 is not y1)
# Output: True
print(x2 is y2)
# Output: False
x3 = [1,2,3]
y3 = [1,2,3]        

print(x3 is y3)
# Out:
# False
# True
# False

# %% [markdown]
# Here, we see that x1 and y1 are integers of same values, so they are equal as well as identical. Same is the case with x2 and y2 (strings).
#
# But x3 and y3 are list. They are equal but not identical. It is because interpreter locates them separately in memory although they are equal.

# %% [markdown]
# # **Membership operators**
# in and not in are the membership operators in Python. They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and dictionary).
#
# In a dictionary we can only test for presence of key, not the value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example #5: Membership operators in Python**

# %%
x = 'Hello world'
y = {1:'a',2:'b'} #dic 
# Output: True
print('H' in x)
# Output: True
print('hello' not in x)
# Output: True
print(1 in y)
# Output: False
print('a' in y)
# Out:
# True
# True
# True
# False

# %% [markdown]
# Here, 'H' is in x but 'hello' is not present in x (remember, Python is case sensitive). Similary, 1 is key and 'a' is the value in dictionary y. Hence, 'a' in y returns False.
